# %%
# !pip install koreanize_matplotlib
# Out:
# Requirement already satisfied: koreanize_matplotlib in c:\users\lg\anaconda3\lib\site-packages (0.1.1)
# Requirement already satisfied: matplotlib in c:\users\lg\anaconda3\lib\site-packages (from koreanize_matplotlib) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lg\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lg\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lg\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lg\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\lg\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lg\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\lg\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lg\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lg\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lg\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.16.0)

# %%
import koreanize_matplotlib
import pandas as pd

df = pd.read_csv("./datas/online_retail.csv")
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID Country
# 541904  2011-12-09 12:50       0.85     12680.0  France
# 541905  2011-12-09 12:50       2.10     12680.0  France
# 541906  2011-12-09 12:50       4.15     12680.0  France
# 541907  2011-12-09 12:50       4.15     12680.0  France
# 541908  2011-12-09 12:50       4.95     12680.0  France

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# 데이터 타입 변환
df['InvoiceNo'] = df['InvoiceNo'].astype('category')
df['StockCode'] = df['StockCode'].astype('category')
df['Description'] = df['Description'].astype('category')
df['Quantity'] = df['Quantity'].astype('int32')
df['InvoiceDate'] = df['InvoiceDate'].astype('category')
df['Country'] = df['Country'].astype('category')
df['CustomerID'] = df['CustomerID'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  category
#  1   StockCode    541909 non-null  category
#  2   Description  540455 non-null  category
#  3   Quantity     541909 non-null  int32
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float32
#  7   Country      541909 non-null  category
# dtypes: category(4), float32(1), float64(1), int32(1), object(1)
# memory usage: 17.5+ MB

# %%
# 수치 타입의 기술 통계
# 이상치 - 음수값은 취소건
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.689453
# std       218.081158      96.759853    1713.568604
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# 범주 타입의 기술 통계
df.describe(exclude='number')
# Out:
#        InvoiceNo StockCode                         Description  \
# count     541909    541909                              540455
# unique     25900      4070                                4223
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq        1114      2313                                2369
#
#              InvoiceDate         Country
# count             541909          541909
# unique             23260              38
# top     2011-10-31 14:41  United Kingdom
# freq                1114          495478

# %% [markdown]
# ### 결측치

# %%
# 결측치 합계
# CustomerID - 비회원 주문일 수 있다.
df.isnull().sum()
df.isnull().mean() * 100
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
sns.heatmap(df.isnull(), cmap='gray')
# Out:
# <Axes: >

# %% [markdown]
# #### 히스토그램으로 수치 변수 시각화

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.689453
# std       218.081158      96.759853    1713.568604
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# 로그값 지우기 - 끝에 세미콜론 붙임
# 기본은 막대 10개 (bins=10)
df.hist(figsize=(10, 6), bins=40);

# %% [markdown]
# #### 전체 주문 금액 변수 만들기

# %%
# TotalPrice = Quantity x Unitprice
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0        2010-12-01 8:26       2.55     17850.0  United Kingdom       15.30
# 1        2010-12-01 8:26       3.39     17850.0  United Kingdom       20.34
# 2        2010-12-01 8:26       2.75     17850.0  United Kingdom       22.00
# 3        2010-12-01 8:26       3.39     17850.0  United Kingdom       20.34
# 4        2010-12-01 8:26       3.39     17850.0  United Kingdom       20.34
# ...                  ...        ...         ...             ...         ...
# 541904  2011-12-09 12:50       0.85     12680.0          France       10.20
# 541905  2011-12-09 12:50       2.10     12680.0          France       12.60
# 541906  2011-12-09 12:50       4.15     12680.0          France       16.60
# 541907  2011-12-09 12:50       4.15     12680.0          France       16.60
# 541908  2011-12-09 12:50       4.95     12680.0          France       14.85
#
# [541909 rows x 9 columns]

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Quantity'}>,
#         <Axes: title={'center': 'UnitPrice'}>],
#        [<Axes: title={'center': 'CustomerID'}>,
#         <Axes: title={'center': 'TotalPrice'}>]], dtype=object)

# %% [markdown]
# #### 회원 vs 비회원 구매

# %%
# CustomerID값이 결측치인 값에 대한 Country 값을 가져와 빈도수를 구함
# 1: normalize = True
# isnull - 비회원, notnull - 회원
df["CustomerID"].isnull().value_counts(1)
# Out:
# CustomerID
# False    0.750733
# True     0.249267
# Name: proportion, dtype: float64

# %%
# 결측치가 아닌 값에 대한 Country 값을 가져와 빈도수를 구함
# loc(조건, 열)
df.loc[df["CustomerID"].notnull(), "Country"].value_counts()
# df.loc[~df["CustomerID"].notnull(), "Country"].value_counts()
# Out:
# Country
# United Kingdom          361878
# Germany                   9495
# France                    8491
# EIRE                      7485
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               1877
# Portugal                  1480
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# USA                        291
# Israel                     250
# Unspecified                244
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     17
# Saudi Arabia                10
# Hong Kong                    0
# Name: count, dtype: int64

# %%
# 회원 가입 여부
df["isRegistered"] = df["CustomerID"].notnull()
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#        InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0  2010-12-01 8:26       2.55     17850.0  United Kingdom       15.30
# 1  2010-12-01 8:26       3.39     17850.0  United Kingdom       20.34
# 2  2010-12-01 8:26       2.75     17850.0  United Kingdom       22.00
# 3  2010-12-01 8:26       3.39     17850.0  United Kingdom       20.34
# 4  2010-12-01 8:26       3.39     17850.0  United Kingdom       20.34
# 5  2010-12-01 8:26       7.65     17850.0  United Kingdom       15.30
# 6  2010-12-01 8:26       4.25     17850.0  United Kingdom       25.50
# 7  2010-12-01 8:28       1.85     17850.0  United Kingdom       11.10
# 8  2010-12-01 8:28       1.85     17850.0  United Kingdom       11.10
# 9  2010-12-01 8:34       1.69     13047.0  United Kingdom       54.08
#
#    isRegistered
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True

# %%
pd.crosstab(df["Country"], df["isRegistered"]).sort_values(True, ascending=False)
# Out:
# isRegistered           False   True
# Country
# United Kingdom        133600  361878
# Germany                    0    9495
# France                    66    8491
# EIRE                     711    7485
# Spain                      0    2533
# Netherlands                0    2371
# Belgium                    0    2069
# Switzerland              125    1877
# Portugal                  39    1480
# Australia                  0    1259
# Norway                     0    1086
# Italy                      0     803
# Channel Islands            0     758
# Finland                    0     695
# Cyprus                     0     622
# Sweden                     0     462
# Austria                    0     401
# Denmark                    0     389
# Japan                      0     358
# Poland                     0     341
# USA                        0     291
# Israel                    47     250
# Unspecified              202     244
# Singapore                  0     229
# Iceland                    0     182
# Canada                     0     151
# Greece                     0     146
# Malta                      0     127
# United Arab Emirates       0      68
# European Community         0      61
# RSA                        0      58
# Lebanon                    0      45
# Lithuania                  0      35
# Brazil                     0      32
# Czech Republic             0      30
# Bahrain                    2      17
# Saudi Arabia               0      10
# Hong Kong                288       0
