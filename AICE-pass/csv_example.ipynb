# %%
import pandas as pd

#csv 불러오기
path = "./datasets/winequality-white.csv"
data = pd.read_csv(path)
# print(data.head())
# print(data.info())

# csv 저장하기
data.to_csv("./outputs/wine_data.csv", index=False)

# %%
# wine_data 사용
file_path = "./outputs/wine_data.csv"
wine_data = pd.read_csv(file_path)
# print(wine_data.info())
# print(wine_data.head())

# quality 칼럼 선택
select_data = wine_data[['quality', 'pH']]
# print(select_data)

# 10개 행 선택
top_10_row = wine_data[:10]
print(top_10_row)

# 인덱스(번호)
value = wine_data.iloc[0, 1]
print(value)

# 행이름, 열이름
value2 = wine_data.loc[0, 'quality']
print(value2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      45.00
# 1            6.3              0.30         0.34             1.6      49.00
# 2            8.1              0.28         0.40             6.9       0.05
# 3            7.2              0.23         0.32             8.5      58.00
# 4            7.2              0.23         0.32             8.5      58.00
# 5            8.1              0.28         0.40             6.9       0.05
# 6            6.2              0.32         0.16             7.0      45.00
# 7            7.0              0.27         0.36            20.7      45.00
# 8            6.3              0.30         0.34             1.6      49.00
# 9            8.1              0.22         0.43             1.5      44.00
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...
