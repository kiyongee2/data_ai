# %%
print("Hello~ World")
# Out:
# Hello~ World

# %%
print("안녕~ 세계")
# Out:
# 안녕~ 세계

# %%
10 + 20
10 - 20
# Out:
# -10

# %%
n1 = 20
n2 = 10

print(n1 + n2)
print(n1 - n2)
print(n1 * n2)
print(n1 / n2)
print(n1 % n2)
# Out:
# 30
# 10
# 200
# 2.0
# 0

# %%
carts = ["계란", "라면", "콩나물"]
print(carts)

for cart in carts:
    print(cart)
# Out:
# ['계란', '라면', '콩나물']
# 계란
# 라면
# 콩나물

# %% [markdown]
# ### 함수 만들기
# * 기능 - 절대값 계산
# * 설명 - 음수는 양수로 양수는 양수로 반환

# %%
def my_abs(x):
    if x < 0:
        return -x
    else:
        return x

print(my_abs(-3))
# Out:
# 3
