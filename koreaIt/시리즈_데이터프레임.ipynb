# %%
import pandas as pd

data = ['키보드', '마우스', 'USB 메모리']

s1 = pd.Series(data, index=[1, 2, 3])
s1
# type(s1)
# Out:
# 1        키보드
# 2        마우스
# 3    USB 메모리
# dtype: object

# %%
# Series의 속성
s1.index
s1.values
s1.shape

# 요소 선택 - 인덱스 
s1[1]
s1[2]
# Out:
# '마우스'

# %%
# 두번째 시리즈
idx = [1, 2, 3]

s2 = pd.Series([20000, 32000, 10000], index = idx)
s2
# s2.shape
# s2.dtype
# Out:
# 1    20000
# 2    32000
# 3    10000
# dtype: int64

# %%
import pandas as pd

df = pd.DataFrame({
    "name": s1,
    "price": s2
})

df
# Out:
#       name  price
# 1      키보드  20000
# 2      마우스  32000
# 3  USB 메모리  10000
